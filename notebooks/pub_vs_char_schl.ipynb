# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# satdistrictdataclass2015 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2015.csv")
# satdistrictdataclass2016 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2016.csv")
# satdistrictdataclass2017 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2017.csv")
# satdistrictdataclass2018 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2018.csv")
# satdistrictdataclass2019 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2019.csv")
# satdistrictdataclass2020 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2020.csv")
# satdistrictdataclass2021 = pd.read_csv("data/texas_data/sat_data/satdistrictdataclass2021.csv")

# %%
# satdistrictdataclass2015['Year'] = 2015
# satdistrictdataclass2016['Year'] = 2016
# satdistrictdataclass2017['Year'] = 2017
# satdistrictdataclass2018['Year'] = 2018
# satdistrictdataclass2019['Year'] = 2019
# satdistrictdataclass2020['Year'] = 2020
# satdistrictdataclass2021['Year'] = 2021

# %%
# dallas_2015 = satdistrictdataclass2015[satdistrictdataclass2015['CntyName'] == 'Dallas County']
# dallas_2016 = satdistrictdataclass2016[satdistrictdataclass2016['CntyName'] == 'Dallas County']
# dallas_2017 = satdistrictdataclass2017[satdistrictdataclass2017['CntyName'] == 'Dallas County']
# dallas_2018 = satdistrictdataclass2018[satdistrictdataclass2018['CntyName'] == 'Dallas County']
# dallas_2019 = satdistrictdataclass2019[satdistrictdataclass2019['CntyName'] == 'Dallas County']
# dallas_2020 = satdistrictdataclass2020[satdistrictdataclass2020['CntyName'] == 'Dallas County']
# dallas_2021 = satdistrictdataclass2021[satdistrictdataclass2021['CntyName'] == 'Dallas County']

# %%
# combined_dallas_data = pd.concat([dallas_2015, dallas_2016,dallas_2017,dallas_2018,dallas_2019,dallas_2020,dallas_2021], ignore_index=True)

# %%
combined_dallas_data = pd.read_csv("C:/Users/Brandon H/Documents/daimil10/cap_stone/sfunding_sat_score/data/texas_data/sat_data/combined_dallas_data.csv")

# %%
print(combined_dallas_data['Year'].unique())
# Out:
# [2015 2016 2017 2018 2019 2020 2021]

# %%
public_schl_df = combined_dallas_data[combined_dallas_data['DistName'].str.contains('ISD')]

# %%
public_schl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4956 entries, 756 to 11015
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                4956 non-null   object
#  1   District             4956 non-null   object
#  2   DistName             4956 non-null   object
#  3   County               4956 non-null   object
#  4   CntyName             4956 non-null   object
#  5   Region               4956 non-null   object
#  6   RegnName             4956 non-null   object
#  7   Math                 3849 non-null   float64
#  8   Reading              848 non-null    float64
#  9   Writing              848 non-null    float64
#  10  Total                3849 non-null   float64
#  11  Grads_Mskd           4956 non-null   object
#  12  Exnees_Mskd          4956 non-null   object
#  13  Part_Rate            3240 non-null   object
#  14  Crit_Mskd            4956 non-null   object
#  15  Above_Crit_Rate      3334 non-null   object
#  16  Year                 4956 non-null   int64
#  17  ERW                  3001 non-null   float64
#  18  TSI_Both_Mskd        3108 non-null   object
#  19  Above_TSI_Both_Rate  2351 non-null   float64
# dtypes: float64(6), int64(1), object(13)
# memory usage: 813.1+ KB

# %%
charter_schl_df = combined_dallas_data[~combined_dallas_data['DistName'].str.contains('ISD')]
charter_schl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6060 entries, 0 to 10217
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                6060 non-null   object
#  1   District             6060 non-null   object
#  2   DistName             6060 non-null   object
#  3   County               6060 non-null   object
#  4   CntyName             6060 non-null   object
#  5   Region               6060 non-null   object
#  6   RegnName             6060 non-null   object
#  7   Math                 2992 non-null   float64
#  8   Reading              644 non-null    float64
#  9   Writing              644 non-null    float64
#  10  Total                2992 non-null   float64
#  11  Grads_Mskd           6060 non-null   object
#  12  Exnees_Mskd          6060 non-null   object
#  13  Part_Rate            2896 non-null   object
#  14  Crit_Mskd            6060 non-null   object
#  15  Above_Crit_Rate      1807 non-null   object
#  16  Year                 6060 non-null   int64
#  17  ERW                  2348 non-null   float64
#  18  TSI_Both_Mskd        3774 non-null   object
#  19  Above_TSI_Both_Rate  1735 non-null   float64
# dtypes: float64(6), int64(1), object(13)
# memory usage: 994.2+ KB

# %%
all_students_df_public = public_schl_df[public_schl_df['Group'] == 'All Students']

public_average_scores_by_year = public_schl_df.groupby('Year')['Total'].mean()

print(public_average_scores_by_year)
# Out:
# Year
# 2015     929.511962
# 2016     916.225581
# 2017     989.700990
# 2018    1021.512158
# 2019    1006.758900
# 2020     999.533898
# 2021     991.863492
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(10, 6))  
plt.plot(public_average_scores_by_year.index, public_average_scores_by_year.values, marker='o') 
plt.title('Average SAT Scores for All Students Over the Years in Public School')
plt.xlabel('Year')
plt.ylabel('Average SAT Score')
plt.grid(True)  
plt.xticks(rotation=45)  
plt.tight_layout()  
plt.show()

# %%
all_students_df_charter = charter_schl_df[charter_schl_df['Group'] == 'All Students']

average_scores_by_year_charter = charter_schl_df.groupby('Year')['Total'].mean()

print(average_scores_by_year_charter)
# Out:
# Year
# 2015    858.833828
# 2016    854.358306
# 2017    961.290954
# 2018    973.159483
# 2019    971.492278
# 2020    966.525253
# 2021    959.049784
# Name: Total, dtype: float64

# %%
plt.figure(figsize=(10, 6))  
plt.plot(average_scores_by_year_charter.index, average_scores_by_year_charter.values, marker='o') 
plt.title('Average SAT Scores for All Students Over the Years in Charter School')
plt.xlabel('Year')
plt.ylabel('Average SAT Score')
plt.grid(True)  
plt.xticks(rotation=45)  
plt.tight_layout()  
plt.show()

# %%
all_students_dfw_df = combined_dallas_data[combined_dallas_data['Group'] == 'All Students']

# %%
avg_total_by_year = all_students_dfw_df.groupby('Year')['Total'].mean()

# %%
print(avg_total_by_year)
# Out:
# Year
# 2015    895.580645
# 2016    887.413793
# 2017    987.225806
# 2018    999.612903
# 2019    997.290323
# 2020    996.433333
# 2021    981.266667
# Name: Total, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(avg_total_by_year.index, avg_total_by_year.values, marker='o')
plt.title('Average Total Scores for Total Students in Dallas County Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Total Score')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("C:/Users/Brandon H/Documents/daimil10/cap_stone/sfunding_sat_score/data/texas_data/sat_data/combined_dallas_data.csv")

# %%
df.isd = df[df['DistName'].str.contains('ISD')]
df.isd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4956 entries, 756 to 11015
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                4956 non-null   object
#  1   District             4956 non-null   object
#  2   DistName             4956 non-null   object
#  3   County               4956 non-null   object
#  4   CntyName             4956 non-null   object
#  5   Region               4956 non-null   object
#  6   RegnName             4956 non-null   object
#  7   Math                 3849 non-null   float64
#  8   Reading              848 non-null    float64
#  9   Writing              848 non-null    float64
#  10  Total                3849 non-null   float64
#  11  Grads_Mskd           4956 non-null   object
#  12  Exnees_Mskd          4956 non-null   object
#  13  Part_Rate            3240 non-null   object
#  14  Crit_Mskd            4956 non-null   object
#  15  Above_Crit_Rate      3334 non-null   object
#  16  Year                 4956 non-null   int64
#  17  ERW                  3001 non-null   float64
#  18  TSI_Both_Mskd        3108 non-null   object
#  19  Above_TSI_Both_Rate  2351 non-null   float64
# dtypes: float64(6), int64(1), object(13)
# memory usage: 813.1+ KB
# C:\Users\Brandon H\AppData\Local\Temp\ipykernel_21780\1441484819.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.isd = df[df['DistName'].str.contains('ISD')]

# %%
all_stu_2011 = df.isd[df.isd['Group'] == 'All Students']
all_stu_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 756 to 10959
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                98 non-null     object
#  1   District             98 non-null     object
#  2   DistName             98 non-null     object
#  3   County               98 non-null     object
#  4   CntyName             98 non-null     object
#  5   Region               98 non-null     object
#  6   RegnName             98 non-null     object
#  7   Math                 98 non-null     float64
#  8   Reading              28 non-null     float64
#  9   Writing              28 non-null     float64
#  10  Total                98 non-null     float64
#  11  Grads_Mskd           98 non-null     object
#  12  Exnees_Mskd          98 non-null     object
#  13  Part_Rate            98 non-null     object
#  14  Crit_Mskd            98 non-null     object
#  15  Above_Crit_Rate      98 non-null     object
#  16  Year                 98 non-null     int64
#  17  ERW                  70 non-null     float64
#  18  TSI_Both_Mskd        56 non-null     object
#  19  Above_TSI_Both_Rate  56 non-null     float64
# dtypes: float64(6), int64(1), object(13)
# memory usage: 16.1+ KB

# %%
df.char = df[~df['DistName'].str.contains('ISD')]
df.char.head()
# Out:
# C:\Users\Brandon H\AppData\Local\Temp\ipykernel_21780\2785994844.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.char = df[~df['DistName'].str.contains('ISD')]
#               Group   District                            DistName  County  \
# 0      All Students  ="057802"  Pegasus School Of Liberal Arts And  ="057"
# 1  African American  ="057802"  Pegasus School Of Liberal Arts And  ="057"
# 2   American Indian  ="057802"  Pegasus School Of Liberal Arts And  ="057"
# 3             Asian  ="057802"  Pegasus School Of Liberal Arts And  ="057"
# 4          Hispanic  ="057802"  Pegasus School Of Liberal Arts And  ="057"
#
#         CntyName Region    RegnName   Math  Reading  Writing  Total  \
# 0  Dallas County  ="10"  Richardson  404.0    412.0    389.0  815.0
# 1  Dallas County  ="10"  Richardson  400.0    450.0    395.0  850.0
# 2  Dallas County  ="10"  Richardson    NaN      NaN      NaN    NaN
# 3  Dallas County  ="10"  Richardson    NaN      NaN      NaN    NaN
# 4  Dallas County  ="10"  Richardson  398.0    405.0    383.0  803.0
#
#   Grads_Mskd Exnees_Mskd Part_Rate Crit_Mskd Above_Crit_Rate  Year  ERW  \
# 0        <50         <50      89.8       <25             NaN  2015  NaN
# 1        <25         <25      66.7       <25             NaN  2015  NaN
# 2        <25         <25       NaN       <25             NaN  2015  NaN
# 3        <25         <25       NaN       <25             NaN  2015  NaN
# 4        <50         <50      90.2       <25             NaN  2015  NaN
#
#   TSI_Both_Mskd  Above_TSI_Both_Rate
# 0           NaN                  NaN
# 1           NaN                  NaN
# 2           NaN                  NaN
# 3           NaN                  NaN
# 4           NaN                  NaN

# %%
all_char_2011 = df.char[df.char['Group'] == 'All Students']
all_char_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 0 to 10161
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Group                120 non-null    object
#  1   District             120 non-null    object
#  2   DistName             120 non-null    object
#  3   County               120 non-null    object
#  4   CntyName             120 non-null    object
#  5   Region               120 non-null    object
#  6   RegnName             120 non-null    object
#  7   Math                 115 non-null    float64
#  8   Reading              32 non-null     float64
#  9   Writing              32 non-null     float64
#  10  Total                115 non-null    float64
#  11  Grads_Mskd           120 non-null    object
#  12  Exnees_Mskd          120 non-null    object
#  13  Part_Rate            112 non-null    object
#  14  Crit_Mskd            120 non-null    object
#  15  Above_Crit_Rate      79 non-null     object
#  16  Year                 120 non-null    int64
#  17  ERW                  83 non-null     float64
#  18  TSI_Both_Mskd        68 non-null     object
#  19  Above_TSI_Both_Rate  65 non-null     float64
# dtypes: float64(6), int64(1), object(13)
# memory usage: 19.7+ KB
